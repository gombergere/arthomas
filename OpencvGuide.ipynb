# %% [markdown]
# <a href="https://colab.research.google.com/github/gombergere/arthomas/blob/master/OpencvGuide.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import files
file=files.upload()
# Out:
#      <input type="file" id="files-278c4e60-5437-4b36-aeb6-70e7cfe8613f" name="files[]" multiple disabled />
#      <output id="result-278c4e60-5437-4b36-aeb6-70e7cfe8613f">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving picasso.png to picasso.png

# %%
image_file='picasso.png'
import numpy as np
import matplotlib.pyplot as plt
import cv2
image = cv2.imread(image_file)
image = cv2.cvtColor(image,cv2.COLOR_BGR2RGB)
plt.imshow(image)
cv2.imwrite('one.jpg',image)
# Out:
# True

# %%
image = cv2.imread(image_file)
image = cv2.cvtColor(image,cv2.COLOR_BGR2GRAY)
plt.imshow(image)
cv2.imwrite('three.jpg',image)
# Out:
# True

# %%
import numpy as np
import matplotlib.pyplot as plt
import cv2
image = cv2.imread(image_file)
image = cv2.cvtColor(image,cv2.COLOR_BGR2GRAY)
plt.imshow(image)
cv2.imwrite('four.jpg',image)
# Out:
# True

# %%
image = cv2.imread(image_file)
image = cv2.cvtColor(image,cv2.COLOR_BGR2HSV)
plt.imshow(image)
cv2.imwrite('five.jpg',image)
# Out:
# True

# %%
image = cv2.imread(image_file)
image = cv2.cvtColor(image,cv2.COLOR_BGR2HSV)
plt.imshow(image)
cv2.imwrite('five.jpg',image)

# %%
image = cv2.imread(image_file)
edges = cv2.Canny(image,200,200) 
plt.imshow(edges)
cv2.imwrite('five.jpg',image)
# Out:
# True

# %%
image = cv2.imread(image_file) 
rows,cols = image.shape[:2] 
M = cv2.getRotationMatrix2D((cols/2,rows/2),90,1) 
image = cv2.warpAffine(image,M,(cols,rows)) 
plt.imshow(image)
cv2.imwrite('six.jpg',image)
# Out:
# True

# %%
image = cv2.imread(image_file) 
rows,cols = image.shape[:2]
M = np.float32([[2,0,-100],[0,2,-100]]) 
image = cv2.warpAffine(image,M,(cols,rows)) 
plt.imshow(image)
cv2.imwrite('seven.jpg',image)
# Out:
# True
