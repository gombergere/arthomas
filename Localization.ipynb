# %% [markdown]
# <a href="https://colab.research.google.com/github/gombergere/arthomas/blob/master/Localization.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#https://colab.research.google.com/drive/1usT_XYE6DLENeUL3__GNCYAWn-0NbVh6#forceEdit=true&sandboxMode=true&scrollTo=Qcn3zdf-I5yl
# Il y a beaucoup de choses intéressantes malgré tout
#...ce n'est pas du TF 2 et Keras est toujours de la partie
#...on voit bien comment les 'box' d'identification sont définies et utilisées

# %%
from tensorflow import keras
from tensorflow.keras import backend as K
import tensorflow as tf
import numpy as np

print( tf.VERSION )
# Out:
# <p style="color: red;">
# The default version of TensorFlow in Colab will soon switch to TensorFlow 2.x.<br>
# We recommend you <a href="https://www.tensorflow.org/guide/migrate" target="_blank">upgrade</a> now
# or ensure your notebook will continue to use TensorFlow 1.x via the <code>%tensorflow_version 1.x</code> magic:
# <a href="https://colab.research.google.com/notebooks/tensorflow_version.ipynb" target="_blank">more info</a>.</p>
# 1.15.0

# %%
# !pip install xmltodict
import requests, zipfile, io

r = requests.get( 'https://github.com/shubham0204/Dataset_Archives/blob/master/image-localization-dataset.zip?raw=true' ) 
z = zipfile.ZipFile(io.BytesIO(r.content))
z.extractall()
# Out:
# Collecting xmltodict
#   Downloading https://files.pythonhosted.org/packages/28/fd/30d5c1d3ac29ce229f6bdc40bbc20b28f716e8b363140c26eff19122d8a5/xmltodict-0.12.0-py2.py3-none-any.whl
# Installing collected packages: xmltodict
# Successfully installed xmltodict-0.12.0

# %%
input_dim = 228
num_classes = 3
pred_vector_length = 4 + num_classes

# %%
from PIL import Image , ImageDraw
import os
import glob

images = []
image_paths = glob.glob( 'training_images/*.jpg' )
for imagefile in image_paths:
    image = Image.open( imagefile ).resize( ( input_dim , input_dim ))
    image = np.asarray( image ) / 255.0
    images.append( image )

# %%
import xmltodict
import os

bboxes = []
classes_raw = []
annotations_paths = glob.glob( 'training_images/*.xml' )
for xmlfile in annotations_paths:
    x = xmltodict.parse( open( xmlfile , 'rb' ) )
    bndbox = x[ 'annotation' ][ 'object' ][ 'bndbox' ]
    bndbox = np.array([ int(bndbox[ 'xmin' ]) , int(bndbox[ 'ymin' ]) , int(bndbox[ 'xmax' ]) , int(bndbox[ 'ymax' ]) ])
    bndbox2 = [ None ] * 4
    bndbox2[0] = bndbox[0]
    bndbox2[1] = bndbox[1]
    bndbox2[2] = bndbox[2]
    bndbox2[3] = bndbox[3]
    bndbox2 = np.array( bndbox2 ) / input_dim
    bboxes.append( bndbox2 )
    classes_raw.append( x[ 'annotation' ][ 'object' ][ 'name' ] )

# %%
from sklearn.preprocessing import LabelBinarizer
from sklearn.model_selection import train_test_split

boxes = np.array( bboxes ) 
encoder = LabelBinarizer()
classes_onehot = encoder.fit_transform( classes_raw )

Y = np.concatenate( [ boxes , classes_onehot ] , axis=1 )
X = np.array( images )

print( X.shape ) 
print( Y.shape )

x_train, x_test, y_train, y_test = train_test_split( X, Y, test_size=0.1 )
# Out:
# (186, 228, 228, 3)
# (186, 7)

# %%
input_shape = ( input_dim , input_dim , 3 )
dropout_rate = 0.5
alpha = 0.2

def calculate_iou( target_boxes , pred_boxes ):
    xA = K.maximum( target_boxes[ ... , 0], pred_boxes[ ... , 0] )
    yA = K.maximum( target_boxes[ ... , 1], pred_boxes[ ... , 1] )
    xB = K.minimum( target_boxes[ ... , 2], pred_boxes[ ... , 2] )
    yB = K.minimum( target_boxes[ ... , 3], pred_boxes[ ... , 3] )
    interArea = K.maximum( 0.0 , xB - xA ) * K.maximum( 0.0 , yB - yA )
    boxAArea = (target_boxes[ ... , 2] - target_boxes[ ... , 0]) * (target_boxes[ ... , 3] - target_boxes[ ... , 1])
    boxBArea = (pred_boxes[ ... , 2] - pred_boxes[ ... , 0]) * (pred_boxes[ ... , 3] - pred_boxes[ ... , 1])
    iou = interArea / ( boxAArea + boxBArea - interArea )
    return iou

def custom_loss( y_true , y_pred ):
    mse = tf.losses.mean_squared_error( y_true , y_pred ) 
    iou = calculate_iou( y_true , y_pred ) 
    return mse + ( 1 - iou )

def iou_metric( y_true , y_pred ):
    return calculate_iou( y_true , y_pred )

# %%
model_layers = [       
	keras.layers.Conv2D(16, kernel_size=(3, 3), strides=1, input_shape=input_shape),
    keras.layers.LeakyReLU( alpha=alpha ) ,
    keras.layers.Conv2D(16, kernel_size=(3, 3), strides=1 ),
    keras.layers.LeakyReLU( alpha=alpha ) ,
    keras.layers.MaxPooling2D( pool_size=( 2 , 2 ) ),

    keras.layers.Conv2D(32, kernel_size=(3, 3), strides=1),
    keras.layers.LeakyReLU( alpha=alpha ) ,
    keras.layers.Conv2D(32, kernel_size=(3, 3), strides=1),
    keras.layers.LeakyReLU( alpha=alpha ) ,
    keras.layers.MaxPooling2D( pool_size=( 2 , 2 ) ),

    keras.layers.Conv2D(64, kernel_size=(3, 3), strides=1),
    keras.layers.LeakyReLU( alpha=alpha ) ,
    keras.layers.Conv2D(64, kernel_size=(3, 3), strides=1),
    keras.layers.LeakyReLU( alpha=alpha ) ,
    keras.layers.MaxPooling2D( pool_size=( 2 , 2 ) ),

    keras.layers.Conv2D(128, kernel_size=(3, 3), strides=1),
    keras.layers.LeakyReLU( alpha=alpha ) ,
    keras.layers.Conv2D(128, kernel_size=(3, 3), strides=1),
    keras.layers.LeakyReLU( alpha=alpha ) ,
    keras.layers.MaxPooling2D( pool_size=( 2 , 2 ) ),

    keras.layers.Conv2D(256, kernel_size=(3, 3), strides=1),
    keras.layers.LeakyReLU( alpha=alpha ) ,
    keras.layers.Conv2D(256, kernel_size=(3, 3), strides=1),
    keras.layers.LeakyReLU( alpha=alpha ) ,
    keras.layers.MaxPooling2D( pool_size=( 2 , 2 ) ),

    keras.layers.Flatten() , 

    keras.layers.Dense( 1240 ) , 
    keras.layers.LeakyReLU( alpha=alpha ) ,
    keras.layers.Dense( 640 ) , 
    keras.layers.LeakyReLU( alpha=alpha ) ,
    keras.layers.Dense( 480 ) , 
    keras.layers.LeakyReLU( alpha=alpha ) ,
    keras.layers.Dense( 120 ) , 
    keras.layers.LeakyReLU( alpha=alpha ) ,
    keras.layers.Dense( 62 ) , 
    keras.layers.LeakyReLU( alpha=alpha ) ,

    keras.layers.Dense( pred_vector_length ),
    keras.layers.LeakyReLU( alpha=alpha ) ,
]

model = keras.Sequential( model_layers )
model.compile(
	optimizer=keras.optimizers.Adam( lr=0.0001 ),
	loss=custom_loss,
    metrics=[ iou_metric ]
)
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow_core/python/ops/resource_variable_ops.py:1630: calling BaseResourceVariable.__init__ (from tensorflow.python.ops.resource_variable_ops) with constraint is deprecated and will be removed in a future version.
# Instructions for updating:
# If using Keras pass *_constraint arguments to layers.
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow_core/python/ops/losses/losses_impl.py:121: where (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where

# %%
model.fit( 
    x_train ,
    y_train , 
    validation_data=( x_test , y_test ),
    epochs=200 ,
    batch_size=3 
)

model.save( 'model.h5')
# Out:
# Train on 167 samples, validate on 19 samples
# Epoch 1/200
# 167/167 [==============================] - 9s 54ms/sample - loss: 0.8443 - iou_metric: 0.3172 - val_loss: 0.7029 - val_iou_metric: 0.4161
# Epoch 2/200
# 167/167 [==============================] - 1s 5ms/sample - loss: 0.5991 - iou_metric: 0.5127 - val_loss: 0.6119 - val_iou_metric: 0.5008
# Epoch 3/200
# 167/167 [==============================] - 1s 5ms/sample - loss: 0.5878 - iou_metric: 0.5204 - val_loss: 0.6129 - val_iou_metric: 0.4956
# Epoch 4/200
# 167/167 [==============================] - 1s 5ms/sample - loss: 0.5812 - iou_metric: 0.5283 - val_loss: 0.6697 - val_iou_metric: 0.4436
# Epoch 5/200
# 167/167 [==============================] - 1s 5ms/sample - loss: 0.5417 - iou_metric: 0.5634 - val_loss: 0.5908 - val_iou_metric: 0.5141
# Epoch 6/200
# 167/167 [==============================] - 1s 5ms/sample - loss: 0.5414 - iou_metric: 0.5639 - val_loss: 0.5627 - val_iou_metric: 0.5455
# Epoch 7/200
# 167/167 [==============================] - 1s 5ms/sample - loss: 0.5427 - iou_metric: 0.5623 - val_loss: 0.6067 - val_iou_metric: 0.5007
# Epoch 8/200
# 167/167 [==============================] - 1s 5ms/sample - loss: 0.5345 - iou_metric: 0.5702 - val_loss: 0.5782 - val_iou_metric: 0.5291
# Epoch 9/200
# 167/167 [==============================] - 1s 5ms/sample - loss: 0.5110 - iou_metric: 0.5922 - val_loss: 0.5778 - val_iou_metric: 0.5272
# Epoch 10/200
# 167/167 [==============================] - 1s 5ms/sample - loss: 0.5332 - iou_metric: 0.5710 - val_loss: 0.5395 - val_iou_metric: 0.5645
# Epoch 11/200
# 167/167 [==============================] - 1s 5ms/sample - loss: 0.5169 - iou_metric: 0.5865 - val_loss: 0.5496 - val_iou_metric: 0.5564
# Epoch 12/200
# 167/167 [==============================] - 1s 5ms/sample - loss: 0.5163 - iou_metric: 0.5870 - val_loss: 0.5668 - val_iou_metric: 0.5379
# Epoch 13/200
# 167/167 [==============================] - 1s 5ms/sample - loss: 0.5099 - iou_metric: 0.5927 - val_loss: 0.5862 - val_iou_metric: 0.5203
# Epoch 14/200
# 167/167 [==============================] - 1s 5ms/sample - loss: 0.5029 - iou_metric: 0.6004 - val_loss: 0.6226 - val_iou_metric: 0.4882
# Epoch 15/200
# 167/167 [==============================] - 1s 5ms/sample - loss: 0.5170 - iou_metric: 0.5866 - val_loss: 0.5460 - val_iou_metric: 0.5574
# Epoch 16/200
# 167/167 [==============================] - 1s 5ms/sample - loss: 0.5230 - iou_metric: 0.5806 - val_loss: 0.5574 - val_iou_metric: 0.5470
# Epoch 17/200
# 167/167 [==============================] - 1s 5ms/sample - loss: 0.5131 - iou_metric: 0.5900 - val_loss: 0.5762 - val_iou_metric: 0.5323
# Epoch 18/200
# 167/167 [==============================] - 1s 5ms/sample - loss: 0.5071 - iou_metric: 0.5958 - val_loss: 0.5399 - val_iou_metric: 0.5652
# Epoch 19/200
# 167/167 [==============================] - 1s 5ms/sample - loss: 0.5174 - iou_metric: 0.5866 - val_loss: 0.5562 - val_iou_metric: 0.5486
# Epoch 20/200
# 167/167 [==============================] - 1s 5ms/sample - loss: 0.5227 - iou_metric: 0.5813 - val_loss: 0.5457 - val_iou_metric: 0.5585
# Epoch 21/200
# 167/167 [==============================] - 1s 5ms/sample - loss: 0.5123 - iou_metric: 0.5909 - val_loss: 0.5528 - val_iou_metric: 0.5511
# Epoch 22/200
# 167/167 [==============================] - 1s 5ms/sample - loss: 0.5005 - iou_metric: 0.6020 - val_loss: 0.5425 - val_iou_metric: 0.5610
# Epoch 23/200
# 167/167 [==============================] - 1s 5ms/sample - loss: 0.5114 - iou_metric: 0.5916 - val_loss: 0.5474 - val_iou_metric: 0.5573
# Epoch 24/200
# 167/167 [==============================] - 1s 5ms/sample - loss: 0.4973 - iou_metric: 0.6050 - val_loss: 0.5692 - val_iou_metric: 0.5369
# Epoch 25/200
# 167/167 [==============================] - 1s 5ms/sample - loss: 0.5068 - iou_metric: 0.5958 - val_loss: 0.5480 - val_iou_metric: 0.5565
# Epoch 26/200
# 167/167 [==============================] - 1s 5ms/sample - loss: 0.5087 - iou_metric: 0.5941 - val_loss: 0.5878 - val_iou_metric: 0.5186
# Epoch 27/200
# 167/167 [==============================] - 1s 5ms/sample - loss: 0.5021 - iou_metric: 0.6005 - val_loss: 0.5500 - val_iou_metric: 0.5553
# Epoch 28/200
# 167/167 [==============================] - 1s 5ms/sample - loss: 0.4977 - iou_metric: 0.6045 - val_loss: 0.5654 - val_iou_metric: 0.5391
# Epoch 29/200
# 167/167 [==============================] - 1s 5ms/sample - loss: 0.4942 - iou_metric: 0.6076 - val_loss: 0.5932 - val_iou_metric: 0.5159
# Epoch 30/200
# 167/167 [==============================] - 1s 5ms/sample - loss: 0.4928 - iou_metric: 0.6096 - val_loss: 0.5457 - val_iou_metric: 0.5583
# Epoch 31/200
# 167/167 [==============================] - 1s 5ms/sample - loss: 0.4873 - iou_metric: 0.6149 - val_loss: 0.5578 - val_iou_metric: 0.5473
# Epoch 32/200
# 167/167 [==============================] - 1s 5ms/sample - loss: 0.4714 - iou_metric: 0.6301 - val_loss: 0.5715 - val_iou_metric: 0.5346
# Epoch 33/200
# 167/167 [==============================] - 1s 5ms/sample - loss: 0.4826 - iou_metric: 0.6188 - val_loss: 0.5689 - val_iou_metric: 0.5375
# Epoch 34/200
# 167/167 [==============================] - 1s 5ms/sample - loss: 0.4770 - iou_metric: 0.6241 - val_loss: 0.5592 - val_iou_metric: 0.5457
# Epoch 35/200
# 167/167 [==============================] - 1s 5ms/sample - loss: 0.4649 - iou_metric: 0.6359 - val_loss: 0.5623 - val_iou_metric: 0.5448
# Epoch 36/200
# 167/167 [==============================] - 1s 5ms/sample - loss: 0.4678 - iou_metric: 0.6334 - val_loss: 0.5777 - val_iou_metric: 0.5274
# Epoch 37/200
# 167/167 [==============================] - 1s 5ms/sample - loss: 0.4624 - iou_metric: 0.6380 - val_loss: 0.5658 - val_iou_metric: 0.5391
# Epoch 38/200
# 167/167 [==============================] - 1s 5ms/sample - loss: 0.4489 - iou_metric: 0.6510 - val_loss: 0.5665 - val_iou_metric: 0.5394
# Epoch 39/200
# 167/167 [==============================] - 1s 5ms/sample - loss: 0.4447 - iou_metric: 0.6540 - val_loss: 0.5751 - val_iou_metric: 0.5307
# Epoch 40/200
# 167/167 [==============================] - 1s 5ms/sample - loss: 0.4527 - iou_metric: 0.6459 - val_loss: 0.5635 - val_iou_metric: 0.5401
# Epoch 41/200
# 167/167 [==============================] - 1s 5ms/sample - loss: 0.4320 - iou_metric: 0.6650 - val_loss: 0.5727 - val_iou_metric: 0.5324
# Epoch 42/200
# 167/167 [==============================] - 1s 5ms/sample - loss: 0.4205 - iou_metric: 0.6759 - val_loss: 0.5702 - val_iou_metric: 0.5336
# Epoch 43/200
# 167/167 [==============================] - 1s 5ms/sample - loss: 0.4098 - iou_metric: 0.6854 - val_loss: 0.5756 - val_iou_metric: 0.5291
# Epoch 44/200
# 167/167 [==============================] - 1s 5ms/sample - loss: 0.3969 - iou_metric: 0.6961 - val_loss: 0.5464 - val_iou_metric: 0.5582
# Epoch 45/200
# 167/167 [==============================] - 1s 5ms/sample - loss: 0.3783 - iou_metric: 0.7138 - val_loss: 0.5876 - val_iou_metric: 0.5208
# Epoch 46/200
# 167/167 [==============================] - 1s 5ms/sample - loss: 0.3974 - iou_metric: 0.6947 - val_loss: 0.5791 - val_iou_metric: 0.5273
# Epoch 47/200
# 167/167 [==============================] - 1s 5ms/sample - loss: 0.3739 - iou_metric: 0.7152 - val_loss: 0.5873 - val_iou_metric: 0.5155
# Epoch 48/200
# 167/167 [==============================] - 1s 5ms/sample - loss: 0.3601 - iou_metric: 0.7275 - val_loss: 0.5848 - val_iou_metric: 0.5183
# Epoch 49/200
# 167/167 [==============================] - 1s 5ms/sample - loss: 0.3597 - iou_metric: 0.7271 - val_loss: 0.5890 - val_iou_metric: 0.5183
# Epoch 50/200
# 167/167 [==============================] - 1s 5ms/sample - loss: 0.3655 - iou_metric: 0.7212 - val_loss: 0.5661 - val_iou_metric: 0.5386
# Epoch 51/200
# 167/167 [==============================] - 1s 5ms/sample - loss: 0.3395 - iou_metric: 0.7455 - val_loss: 0.5770 - val_iou_metric: 0.5271
# Epoch 52/200
# 167/167 [==============================] - 1s 5ms/sample - loss: 0.3219 - iou_metric: 0.7607 - val_loss: 0.5723 - val_iou_metric: 0.5330
# Epoch 53/200
# 167/167 [==============================] - 1s 5ms/sample - loss: 0.3268 - iou_metric: 0.7541 - val_loss: 0.6013 - val_iou_metric: 0.5033
# Epoch 54/200
# 167/167 [==============================] - 1s 5ms/sample - loss: 0.3109 - iou_metric: 0.7679 - val_loss: 0.5753 - val_iou_metric: 0.5358
# Epoch 55/200
# 167/167 [==============================] - 1s 5ms/sample - loss: 0.3240 - iou_metric: 0.7559 - val_loss: 0.5709 - val_iou_metric: 0.5350
# Epoch 56/200
# 167/167 [==============================] - 1s 5ms/sample - loss: 0.3199 - iou_metric: 0.7583 - val_loss: 0.5764 - val_iou_metric: 0.5299
# Epoch 57/200
# 167/167 [==============================] - 1s 5ms/sample - loss: 0.3046 - iou_metric: 0.7721 - val_loss: 0.5682 - val_iou_metric: 0.5387
# Epoch 58/200
# 167/167 [==============================] - 1s 5ms/sample - loss: 0.3026 - iou_metric: 0.7730 - val_loss: 0.5681 - val_iou_metric: 0.5376
# Epoch 59/200
# 167/167 [==============================] - 1s 5ms/sample - loss: 0.3074 - iou_metric: 0.7662 - val_loss: 0.5686 - val_iou_metric: 0.5341
# Epoch 60/200
# 167/167 [==============================] - 1s 5ms/sample - loss: 0.3012 - iou_metric: 0.7714 - val_loss: 0.6099 - val_iou_metric: 0.5031
# Epoch 61/200
# 167/167 [==============================] - 1s 5ms/sample - loss: 0.2869 - iou_metric: 0.7843 - val_loss: 0.5864 - val_iou_metric: 0.5157
# Epoch 62/200
# 167/167 [==============================] - 1s 5ms/sample - loss: 0.2947 - iou_metric: 0.7745 - val_loss: 0.5799 - val_iou_metric: 0.5253
# Epoch 63/200
# 167/167 [==============================] - 1s 5ms/sample - loss: 0.2914 - iou_metric: 0.7768 - val_loss: 0.5653 - val_iou_metric: 0.5348
# Epoch 64/200
# 167/167 [==============================] - 1s 5ms/sample - loss: 0.2655 - iou_metric: 0.7999 - val_loss: 0.5906 - val_iou_metric: 0.5179
# Epoch 65/200
# 167/167 [==============================] - 1s 5ms/sample - loss: 0.2578 - iou_metric: 0.8067 - val_loss: 0.5788 - val_iou_metric: 0.5306
# Epoch 66/200
# 167/167 [==============================] - 1s 5ms/sample - loss: 0.2693 - iou_metric: 0.7940 - val_loss: 0.5921 - val_iou_metric: 0.5172
# Epoch 67/200
# 167/167 [==============================] - 1s 5ms/sample - loss: 0.2731 - iou_metric: 0.7892 - val_loss: 0.5774 - val_iou_metric: 0.5323
# Epoch 68/200
# 167/167 [==============================] - 1s 5ms/sample - loss: 0.2579 - iou_metric: 0.8020 - val_loss: 0.5728 - val_iou_metric: 0.5353
# Epoch 69/200
# 167/167 [==============================] - 1s 5ms/sample - loss: 0.2476 - iou_metric: 0.8120 - val_loss: 0.5747 - val_iou_metric: 0.5318
# Epoch 70/200
# 167/167 [==============================] - 1s 5ms/sample - loss: 0.2476 - iou_metric: 0.8098 - val_loss: 0.5841 - val_iou_metric: 0.5279
# Epoch 71/200
# 167/167 [==============================] - 1s 5ms/sample - loss: 0.2359 - iou_metric: 0.8200 - val_loss: 0.5740 - val_iou_metric: 0.5348
# Epoch 72/200
# 167/167 [==============================] - 1s 5ms/sample - loss: 0.2334 - iou_metric: 0.8224 - val_loss: 0.5931 - val_iou_metric: 0.5245
# Epoch 73/200
# 167/167 [==============================] - 1s 5ms/sample - loss: 0.2235 - iou_metric: 0.8271 - val_loss: 0.5787 - val_iou_metric: 0.5363
# Epoch 74/200
# 167/167 [==============================] - 1s 5ms/sample - loss: 0.2311 - iou_metric: 0.8177 - val_loss: 0.5841 - val_iou_metric: 0.5294
# Epoch 75/200
# 167/167 [==============================] - 1s 5ms/sample - loss: 0.2318 - iou_metric: 0.8144 - val_loss: 0.5909 - val_iou_metric: 0.5228
# Epoch 76/200
# 167/167 [==============================] - 1s 5ms/sample - loss: 0.2072 - iou_metric: 0.8371 - val_loss: 0.5653 - val_iou_metric: 0.5474
# Epoch 77/200
# 167/167 [==============================] - 1s 5ms/sample - loss: 0.2162 - iou_metric: 0.8245 - val_loss: 0.5885 - val_iou_metric: 0.5334
# Epoch 78/200
# 167/167 [==============================] - 1s 5ms/sample - loss: 0.1998 - iou_metric: 0.8364 - val_loss: 0.5948 - val_iou_metric: 0.5312
# Epoch 79/200
# 167/167 [==============================] - 1s 5ms/sample - loss: 0.2054 - iou_metric: 0.8305 - val_loss: 0.5899 - val_iou_metric: 0.5285
# Epoch 80/200
# 167/167 [==============================] - 1s 5ms/sample - loss: 0.2076 - iou_metric: 0.8252 - val_loss: 0.5927 - val_iou_metric: 0.5287
# Epoch 81/200
# 167/167 [==============================] - 1s 5ms/sample - loss: 0.1917 - iou_metric: 0.8375 - val_loss: 0.5953 - val_iou_metric: 0.5279
# Epoch 82/200
# 167/167 [==============================] - 1s 5ms/sample - loss: 0.1851 - iou_metric: 0.8420 - val_loss: 0.5969 - val_iou_metric: 0.5333
# Epoch 83/200
# 167/167 [==============================] - 1s 5ms/sample - loss: 0.1674 - iou_metric: 0.8559 - val_loss: 0.5860 - val_iou_metric: 0.5380
# Epoch 84/200
# 167/167 [==============================] - 1s 5ms/sample - loss: 0.1718 - iou_metric: 0.8504 - val_loss: 0.5994 - val_iou_metric: 0.5328
# Epoch 85/200
# 167/167 [==============================] - 1s 5ms/sample - loss: 0.1783 - iou_metric: 0.8410 - val_loss: 0.5987 - val_iou_metric: 0.5303
# Epoch 86/200
# 167/167 [==============================] - 1s 5ms/sample - loss: 0.1653 - iou_metric: 0.8511 - val_loss: 0.6093 - val_iou_metric: 0.5293
# Epoch 87/200
# 167/167 [==============================] - 1s 5ms/sample - loss: 0.1678 - iou_metric: 0.8474 - val_loss: 0.6058 - val_iou_metric: 0.5359
# Epoch 88/200
# 167/167 [==============================] - 1s 5ms/sample - loss: 0.1637 - iou_metric: 0.8494 - val_loss: 0.6023 - val_iou_metric: 0.5277
# Epoch 89/200
# 167/167 [==============================] - 1s 5ms/sample - loss: 0.1500 - iou_metric: 0.8619 - val_loss: 0.6202 - val_iou_metric: 0.5199
# Epoch 90/200
# 167/167 [==============================] - 1s 5ms/sample - loss: 0.1625 - iou_metric: 0.8484 - val_loss: 0.6105 - val_iou_metric: 0.5374
# Epoch 91/200
# 167/167 [==============================] - 1s 5ms/sample - loss: 0.1563 - iou_metric: 0.8522 - val_loss: 0.6080 - val_iou_metric: 0.5288
# Epoch 92/200
# 167/167 [==============================] - 1s 5ms/sample - loss: 0.1550 - iou_metric: 0.8540 - val_loss: 0.6044 - val_iou_metric: 0.5321
# Epoch 93/200
# 167/167 [==============================] - 1s 5ms/sample - loss: 0.1535 - iou_metric: 0.8557 - val_loss: 0.6076 - val_iou_metric: 0.5358
# Epoch 94/200
# 167/167 [==============================] - 1s 5ms/sample - loss: 0.1417 - iou_metric: 0.8652 - val_loss: 0.6066 - val_iou_metric: 0.5344
# Epoch 95/200
# 167/167 [==============================] - 1s 5ms/sample - loss: 0.1517 - iou_metric: 0.8567 - val_loss: 0.6031 - val_iou_metric: 0.5351
# Epoch 96/200
# 167/167 [==============================] - 1s 5ms/sample - loss: 0.1412 - iou_metric: 0.8652 - val_loss: 0.6028 - val_iou_metric: 0.5345
# Epoch 97/200
# 167/167 [==============================] - 1s 5ms/sample - loss: 0.1349 - iou_metric: 0.8724 - val_loss: 0.6001 - val_iou_metric: 0.5402
# Epoch 98/200
# 167/167 [==============================] - 1s 5ms/sample - loss: 0.1247 - iou_metric: 0.8811 - val_loss: 0.5975 - val_iou_metric: 0.5381
# Epoch 99/200
# 167/167 [==============================] - 1s 5ms/sample - loss: 0.1302 - iou_metric: 0.8749 - val_loss: 0.5939 - val_iou_metric: 0.5433
# Epoch 100/200
# 167/167 [==============================] - 1s 5ms/sample - loss: 0.1399 - iou_metric: 0.8658 - val_loss: 0.5914 - val_iou_metric: 0.5464
# Epoch 101/200
# 167/167 [==============================] - 1s 5ms/sample - loss: 0.1414 - iou_metric: 0.8650 - val_loss: 0.5819 - val_iou_metric: 0.5483
# Epoch 102/200
# 167/167 [==============================] - 1s 5ms/sample - loss: 0.1398 - iou_metric: 0.8657 - val_loss: 0.6271 - val_iou_metric: 0.5209
# Epoch 103/200
# 167/167 [==============================] - 1s 5ms/sample - loss: 0.1325 - iou_metric: 0.8711 - val_loss: 0.5981 - val_iou_metric: 0.5400
# Epoch 104/200
# 167/167 [==============================] - 1s 5ms/sample - loss: 0.1293 - iou_metric: 0.8749 - val_loss: 0.5908 - val_iou_metric: 0.5413
# Epoch 105/200
# 167/167 [==============================] - 1s 5ms/sample - loss: 0.1253 - iou_metric: 0.8781 - val_loss: 0.6079 - val_iou_metric: 0.5311
# Epoch 106/200
# 167/167 [==============================] - 1s 5ms/sample - loss: 0.1346 - iou_metric: 0.8694 - val_loss: 0.5958 - val_iou_metric: 0.5358
# Epoch 107/200
# 167/167 [==============================] - 1s 5ms/sample - loss: 0.1325 - iou_metric: 0.8710 - val_loss: 0.5797 - val_iou_metric: 0.5482
# Epoch 108/200
# 167/167 [==============================] - 1s 5ms/sample - loss: 0.1193 - iou_metric: 0.8849 - val_loss: 0.5928 - val_iou_metric: 0.5391
# Epoch 109/200
# 167/167 [==============================] - 1s 5ms/sample - loss: 0.1128 - iou_metric: 0.8901 - val_loss: 0.5962 - val_iou_metric: 0.5433
# Epoch 110/200
# 167/167 [==============================] - 1s 5ms/sample - loss: 0.1178 - iou_metric: 0.8858 - val_loss: 0.5923 - val_iou_metric: 0.5438
# Epoch 111/200
# 167/167 [==============================] - 1s 5ms/sample - loss: 0.1198 - iou_metric: 0.8839 - val_loss: 0.5805 - val_iou_metric: 0.5448
# Epoch 112/200
# 167/167 [==============================] - 1s 5ms/sample - loss: 0.1299 - iou_metric: 0.8752 - val_loss: 0.5882 - val_iou_metric: 0.5454
# Epoch 113/200
# 167/167 [==============================] - 1s 5ms/sample - loss: 0.1257 - iou_metric: 0.8774 - val_loss: 0.5992 - val_iou_metric: 0.5336
# Epoch 114/200
# 167/167 [==============================] - 1s 5ms/sample - loss: 0.1261 - iou_metric: 0.8773 - val_loss: 0.5812 - val_iou_metric: 0.5507
# Epoch 115/200
# 167/167 [==============================] - 1s 5ms/sample - loss: 0.1158 - iou_metric: 0.8872 - val_loss: 0.5871 - val_iou_metric: 0.5456
# Epoch 116/200
# 167/167 [==============================] - 1s 5ms/sample - loss: 0.1192 - iou_metric: 0.8843 - val_loss: 0.5919 - val_iou_metric: 0.5446
# Epoch 117/200
# 167/167 [==============================] - 1s 5ms/sample - loss: 0.1267 - iou_metric: 0.8765 - val_loss: 0.5925 - val_iou_metric: 0.5362
# Epoch 118/200
# 167/167 [==============================] - 1s 5ms/sample - loss: 0.1186 - iou_metric: 0.8854 - val_loss: 0.5813 - val_iou_metric: 0.5476
# Epoch 119/200
# 167/167 [==============================] - 1s 5ms/sample - loss: 0.1224 - iou_metric: 0.8800 - val_loss: 0.5841 - val_iou_metric: 0.5438
# Epoch 120/200
# 167/167 [==============================] - 1s 5ms/sample - loss: 0.1200 - iou_metric: 0.8827 - val_loss: 0.5825 - val_iou_metric: 0.5499
# Epoch 121/200
# 167/167 [==============================] - 1s 5ms/sample - loss: 0.1240 - iou_metric: 0.8790 - val_loss: 0.5973 - val_iou_metric: 0.5435
# Epoch 122/200
# 167/167 [==============================] - 1s 5ms/sample - loss: 0.1140 - iou_metric: 0.8887 - val_loss: 0.5870 - val_iou_metric: 0.5471
# Epoch 123/200
# 167/167 [==============================] - 1s 5ms/sample - loss: 0.1134 - iou_metric: 0.8895 - val_loss: 0.5989 - val_iou_metric: 0.5390
# Epoch 124/200
# 167/167 [==============================] - 1s 5ms/sample - loss: 0.0998 - iou_metric: 0.9023 - val_loss: 0.5977 - val_iou_metric: 0.5337
# Epoch 125/200
# 167/167 [==============================] - 1s 5ms/sample - loss: 0.1256 - iou_metric: 0.8773 - val_loss: 0.5912 - val_iou_metric: 0.5487
# Epoch 126/200
# 167/167 [==============================] - 1s 5ms/sample - loss: 0.0983 - iou_metric: 0.9035 - val_loss: 0.6084 - val_iou_metric: 0.5368
# Epoch 127/200
# 167/167 [==============================] - 1s 5ms/sample - loss: 0.1098 - iou_metric: 0.8933 - val_loss: 0.5939 - val_iou_metric: 0.5393
# Epoch 128/200
# 167/167 [==============================] - 1s 5ms/sample - loss: 0.1151 - iou_metric: 0.8871 - val_loss: 0.5956 - val_iou_metric: 0.5364
# Epoch 129/200
# 167/167 [==============================] - 1s 5ms/sample - loss: 0.1020 - iou_metric: 0.9003 - val_loss: 0.5857 - val_iou_metric: 0.5483
# Epoch 130/200
# 167/167 [==============================] - 1s 5ms/sample - loss: 0.1145 - iou_metric: 0.8879 - val_loss: 0.5842 - val_iou_metric: 0.5447
# Epoch 131/200
# 167/167 [==============================] - 1s 5ms/sample - loss: 0.1125 - iou_metric: 0.8899 - val_loss: 0.6006 - val_iou_metric: 0.5455
# Epoch 132/200
# 167/167 [==============================] - 1s 5ms/sample - loss: 0.0975 - iou_metric: 0.9048 - val_loss: 0.6092 - val_iou_metric: 0.5345
# Epoch 133/200
# 167/167 [==============================] - 1s 5ms/sample - loss: 0.1076 - iou_metric: 0.8946 - val_loss: 0.5900 - val_iou_metric: 0.5455
# Epoch 134/200
# 167/167 [==============================] - 1s 5ms/sample - loss: 0.1068 - iou_metric: 0.8954 - val_loss: 0.5935 - val_iou_metric: 0.5477
# Epoch 135/200
# 167/167 [==============================] - 1s 5ms/sample - loss: 0.1049 - iou_metric: 0.8977 - val_loss: 0.5902 - val_iou_metric: 0.5464
# Epoch 136/200
# 167/167 [==============================] - 1s 5ms/sample - loss: 0.1037 - iou_metric: 0.8982 - val_loss: 0.5913 - val_iou_metric: 0.5483
# Epoch 137/200
# 167/167 [==============================] - 1s 5ms/sample - loss: 0.1046 - iou_metric: 0.8969 - val_loss: 0.5876 - val_iou_metric: 0.5495
# Epoch 138/200
# 167/167 [==============================] - 1s 5ms/sample - loss: 0.1051 - iou_metric: 0.8969 - val_loss: 0.5976 - val_iou_metric: 0.5318
# Epoch 139/200
# 167/167 [==============================] - 1s 5ms/sample - loss: 0.1013 - iou_metric: 0.9007 - val_loss: 0.5742 - val_iou_metric: 0.5531
# Epoch 140/200
# 167/167 [==============================] - 1s 5ms/sample - loss: 0.0994 - iou_metric: 0.9022 - val_loss: 0.5851 - val_iou_metric: 0.5448
# Epoch 141/200
# 167/167 [==============================] - 1s 5ms/sample - loss: 0.0986 - iou_metric: 0.9038 - val_loss: 0.5863 - val_iou_metric: 0.5480
# Epoch 142/200
# 167/167 [==============================] - 1s 5ms/sample - loss: 0.1097 - iou_metric: 0.8921 - val_loss: 0.5886 - val_iou_metric: 0.5434
# Epoch 143/200
# 167/167 [==============================] - 1s 5ms/sample - loss: 0.0956 - iou_metric: 0.9065 - val_loss: 0.5860 - val_iou_metric: 0.5461
# Epoch 144/200
# 167/167 [==============================] - 1s 5ms/sample - loss: 0.1027 - iou_metric: 0.8992 - val_loss: 0.5834 - val_iou_metric: 0.5462
# Epoch 145/200
# 167/167 [==============================] - 1s 5ms/sample - loss: 0.0902 - iou_metric: 0.9109 - val_loss: 0.5855 - val_iou_metric: 0.5436
# Epoch 146/200
# 167/167 [==============================] - 1s 5ms/sample - loss: 0.1003 - iou_metric: 0.9012 - val_loss: 0.5763 - val_iou_metric: 0.5537
# Epoch 147/200
# 167/167 [==============================] - 1s 5ms/sample - loss: 0.0968 - iou_metric: 0.9046 - val_loss: 0.5916 - val_iou_metric: 0.5422
# Epoch 148/200
# 167/167 [==============================] - 1s 5ms/sample - loss: 0.1003 - iou_metric: 0.9011 - val_loss: 0.5908 - val_iou_metric: 0.5449
# Epoch 149/200
# 167/167 [==============================] - 1s 5ms/sample - loss: 0.0980 - iou_metric: 0.9040 - val_loss: 0.5827 - val_iou_metric: 0.5465
# Epoch 150/200
# 167/167 [==============================] - 1s 5ms/sample - loss: 0.1017 - iou_metric: 0.9002 - val_loss: 0.5833 - val_iou_metric: 0.5482
# Epoch 151/200
# 167/167 [==============================] - 1s 5ms/sample - loss: 0.0985 - iou_metric: 0.9029 - val_loss: 0.5736 - val_iou_metric: 0.5514
# Epoch 152/200
# 167/167 [==============================] - 1s 5ms/sample - loss: 0.0954 - iou_metric: 0.9061 - val_loss: 0.5823 - val_iou_metric: 0.5451
# Epoch 153/200
# 167/167 [==============================] - 1s 5ms/sample - loss: 0.1003 - iou_metric: 0.9011 - val_loss: 0.5677 - val_iou_metric: 0.5500
# Epoch 154/200
# 167/167 [==============================] - 1s 5ms/sample - loss: 0.0885 - iou_metric: 0.9129 - val_loss: 0.5854 - val_iou_metric: 0.5449
# Epoch 155/200
# 167/167 [==============================] - 1s 5ms/sample - loss: 0.0928 - iou_metric: 0.9086 - val_loss: 0.5796 - val_iou_metric: 0.5498
# Epoch 156/200
# 167/167 [==============================] - 1s 5ms/sample - loss: 0.0985 - iou_metric: 0.9029 - val_loss: 0.5767 - val_iou_metric: 0.5519
# Epoch 157/200
# 167/167 [==============================] - 1s 5ms/sample - loss: 0.1003 - iou_metric: 0.9012 - val_loss: 0.5844 - val_iou_metric: 0.5576
# Epoch 158/200
# 167/167 [==============================] - 1s 5ms/sample - loss: 0.0933 - iou_metric: 0.9081 - val_loss: 0.5843 - val_iou_metric: 0.5462
# Epoch 159/200
# 167/167 [==============================] - 1s 5ms/sample - loss: 0.0923 - iou_metric: 0.9092 - val_loss: 0.5821 - val_iou_metric: 0.5539
# Epoch 160/200
# 167/167 [==============================] - 1s 5ms/sample - loss: 0.0928 - iou_metric: 0.9093 - val_loss: 0.5774 - val_iou_metric: 0.5560
# Epoch 161/200
# 167/167 [==============================] - 1s 5ms/sample - loss: 0.1052 - iou_metric: 0.8962 - val_loss: 0.6095 - val_iou_metric: 0.5354
# Epoch 162/200
# 167/167 [==============================] - 1s 5ms/sample - loss: 0.1046 - iou_metric: 0.8969 - val_loss: 0.5734 - val_iou_metric: 0.5511
# Epoch 163/200
# 167/167 [==============================] - 1s 5ms/sample - loss: 0.0942 - iou_metric: 0.9071 - val_loss: 0.5837 - val_iou_metric: 0.5441
# Epoch 164/200
# 167/167 [==============================] - 1s 5ms/sample - loss: 0.1020 - iou_metric: 0.8998 - val_loss: 0.5863 - val_iou_metric: 0.5459
# Epoch 165/200
# 167/167 [==============================] - 1s 5ms/sample - loss: 0.0907 - iou_metric: 0.9106 - val_loss: 0.5870 - val_iou_metric: 0.5484
# Epoch 166/200
# 167/167 [==============================] - 1s 5ms/sample - loss: 0.0892 - iou_metric: 0.9123 - val_loss: 0.5840 - val_iou_metric: 0.5451
# Epoch 167/200
# 167/167 [==============================] - 1s 5ms/sample - loss: 0.0903 - iou_metric: 0.9109 - val_loss: 0.5682 - val_iou_metric: 0.5567
# Epoch 168/200
# 167/167 [==============================] - 1s 5ms/sample - loss: 0.0890 - iou_metric: 0.9125 - val_loss: 0.5761 - val_iou_metric: 0.5510
# Epoch 169/200
# 167/167 [==============================] - 1s 5ms/sample - loss: 0.0919 - iou_metric: 0.9095 - val_loss: 0.5748 - val_iou_metric: 0.5570
# Epoch 170/200
# 167/167 [==============================] - 1s 5ms/sample - loss: 0.0855 - iou_metric: 0.9159 - val_loss: 0.5760 - val_iou_metric: 0.5522
# Epoch 171/200
# 167/167 [==============================] - 1s 5ms/sample - loss: 0.0959 - iou_metric: 0.9054 - val_loss: 0.5785 - val_iou_metric: 0.5538
# Epoch 172/200
# 167/167 [==============================] - 1s 5ms/sample - loss: 0.0935 - iou_metric: 0.9079 - val_loss: 0.5732 - val_iou_metric: 0.5549
# Epoch 173/200
# 167/167 [==============================] - 1s 5ms/sample - loss: 0.0908 - iou_metric: 0.9104 - val_loss: 0.5882 - val_iou_metric: 0.5422
# Epoch 174/200
# 167/167 [==============================] - 1s 5ms/sample - loss: 0.0897 - iou_metric: 0.9117 - val_loss: 0.5786 - val_iou_metric: 0.5524
# Epoch 175/200
# 167/167 [==============================] - 1s 5ms/sample - loss: 0.0787 - iou_metric: 0.9226 - val_loss: 0.5808 - val_iou_metric: 0.5484
# Epoch 176/200
# 167/167 [==============================] - 1s 5ms/sample - loss: 0.0897 - iou_metric: 0.9115 - val_loss: 0.5800 - val_iou_metric: 0.5442
# Epoch 177/200
# 167/167 [==============================] - 1s 5ms/sample - loss: 0.0920 - iou_metric: 0.9096 - val_loss: 0.5820 - val_iou_metric: 0.5528
# Epoch 178/200
# 167/167 [==============================] - 1s 5ms/sample - loss: 0.0894 - iou_metric: 0.9122 - val_loss: 0.5893 - val_iou_metric: 0.5368
# Epoch 179/200
# 167/167 [==============================] - 1s 5ms/sample - loss: 0.0892 - iou_metric: 0.9124 - val_loss: 0.5913 - val_iou_metric: 0.5412
# Epoch 180/200
# 167/167 [==============================] - 1s 5ms/sample - loss: 0.0930 - iou_metric: 0.9081 - val_loss: 0.5927 - val_iou_metric: 0.5463
# Epoch 181/200
# 167/167 [==============================] - 1s 5ms/sample - loss: 0.0840 - iou_metric: 0.9172 - val_loss: 0.5707 - val_iou_metric: 0.5610
# Epoch 182/200
# 167/167 [==============================] - 1s 5ms/sample - loss: 0.0882 - iou_metric: 0.9134 - val_loss: 0.5816 - val_iou_metric: 0.5409
# Epoch 183/200
# 167/167 [==============================] - 1s 5ms/sample - loss: 0.0882 - iou_metric: 0.9132 - val_loss: 0.5734 - val_iou_metric: 0.5519
# Epoch 184/200
# 167/167 [==============================] - 1s 5ms/sample - loss: 0.0781 - iou_metric: 0.9231 - val_loss: 0.5842 - val_iou_metric: 0.5480
# Epoch 185/200
# 167/167 [==============================] - 1s 5ms/sample - loss: 0.0842 - iou_metric: 0.9170 - val_loss: 0.5788 - val_iou_metric: 0.5463
# Epoch 186/200
# 167/167 [==============================] - 1s 5ms/sample - loss: 0.0846 - iou_metric: 0.9166 - val_loss: 0.5877 - val_iou_metric: 0.5490
# Epoch 187/200
# 167/167 [==============================] - 1s 5ms/sample - loss: 0.0923 - iou_metric: 0.9091 - val_loss: 0.5788 - val_iou_metric: 0.5541
# Epoch 188/200
# 167/167 [==============================] - 1s 5ms/sample - loss: 0.0864 - iou_metric: 0.9150 - val_loss: 0.5810 - val_iou_metric: 0.5496
# Epoch 189/200
# 167/167 [==============================] - 1s 5ms/sample - loss: 0.0846 - iou_metric: 0.9169 - val_loss: 0.5882 - val_iou_metric: 0.5509
# Epoch 190/200
# 167/167 [==============================] - 1s 5ms/sample - loss: 0.0907 - iou_metric: 0.9107 - val_loss: 0.5769 - val_iou_metric: 0.5546
# Epoch 191/200
# 167/167 [==============================] - 1s 5ms/sample - loss: 0.0884 - iou_metric: 0.9128 - val_loss: 0.5739 - val_iou_metric: 0.5544
# Epoch 192/200
# 167/167 [==============================] - 1s 5ms/sample - loss: 0.0846 - iou_metric: 0.9167 - val_loss: 0.5838 - val_iou_metric: 0.5462
# Epoch 193/200
# 167/167 [==============================] - 1s 5ms/sample - loss: 0.0861 - iou_metric: 0.9149 - val_loss: 0.5907 - val_iou_metric: 0.5457
# Epoch 194/200
# 167/167 [==============================] - 1s 5ms/sample - loss: 0.0985 - iou_metric: 0.9031 - val_loss: 0.5817 - val_iou_metric: 0.5496
# Epoch 195/200
# 167/167 [==============================] - 1s 5ms/sample - loss: 0.0839 - iou_metric: 0.9172 - val_loss: 0.5854 - val_iou_metric: 0.5522
# Epoch 196/200
# 167/167 [==============================] - 1s 5ms/sample - loss: 0.0812 - iou_metric: 0.9198 - val_loss: 0.5888 - val_iou_metric: 0.5458
# Epoch 197/200
# 167/167 [==============================] - 1s 5ms/sample - loss: 0.0903 - iou_metric: 0.9114 - val_loss: 0.5723 - val_iou_metric: 0.5527
# Epoch 198/200
# 167/167 [==============================] - 1s 5ms/sample - loss: 0.0842 - iou_metric: 0.9169 - val_loss: 0.5818 - val_iou_metric: 0.5527
# Epoch 199/200
# 167/167 [==============================] - 1s 5ms/sample - loss: 0.0921 - iou_metric: 0.9090 - val_loss: 0.5872 - val_iou_metric: 0.5547
# Epoch 200/200
# 167/167 [==============================] - 1s 5ms/sample - loss: 0.0857 - iou_metric: 0.9154 - val_loss: 0.5761 - val_iou_metric: 0.5560

# %%
# !mkdir -v inference_images

boxes = model.predict( x_test )
for i in range( boxes.shape[0] ):
    b = boxes[ i , 0 : 4 ] * input_dim
    img = x_test[i] * 255
    source_img = Image.fromarray( img.astype( np.uint8 ) , 'RGB' )
    draw = ImageDraw.Draw( source_img )
    draw.rectangle( b , outline="black" )
    source_img.save( 'inference_images/image_{}.png'.format( i + 1 ) , 'png' )
# Out:
# mkdir: cannot create directory ‘inference_images’: File exists
